# %%
import pandas as pd
import psycopg2

# %%
# Connect to PostgreSQL

conn = psycopg2.connect(
    host="localhost",
    database="bank_apps_reviews",
    user="bank_admin",
    password="admin123"
)

# %%
# Define a Helper Function to Run SQL and Return DataFrame

def run_query(sql):
    return pd.read_sql(sql, conn)

# %%
sql = "SELECT * FROM reviews;"

run_query(sql)
# Out:
# C:\Users\Jose\AppData\Local\Temp\ipykernel_17248\1241105332.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, conn)
#                                  review_id  \
# 0     a6cbfa34-f2b1-4a16-96b6-c94f58cea76f
# 1     fc67d12c-92e2-45aa-a9e0-011f58a583bc
# 2     11306fb9-5571-4950-8d32-604c5402242f
# 3     809c46d2-730e-446a-9061-2a45e978ad9d
# 4     f28a3a3c-eb94-4aab-88d2-89bcecebcc7b
# ...                                    ...
# 1120  e1c1214a-8bc1-45db-bc49-3d51dddc6b88
# 1121  8d1d472b-2bae-4749-b089-5632108ade02
# 1122  749851ed-72d7-4f1c-8e5e-27dd822b5008
# 1123  f2852962-b983-44af-b296-241a3373477f
# 1124  62102c1c-85b0-4965-b033-063c67ac9129
#
#                                             review_text  rating review_date  \
# ...

# %%
sql = "SELECT * FROM banks;"

run_query(sql)
# Out:
# C:\Users\Jose\AppData\Local\Temp\ipykernel_17248\1241105332.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, conn)
#    bank_id                        app_id                        title  score  \
# 0        1  com.combanketh.mobilebanking  Commercial Bank of Ethiopia   4.32
# 1        2      com.boa.boaMobileBanking                   BoA Mobile   4.19
# 2        3     com.dashen.dashensuperapp                  Dashen Bank   4.16
#
#    ratings  reviews    installs bank_code                    bank_name
# 0    38862     8336  5,000,000+       CBE  Commercial Bank of Ethiopia
# 1     6358     1219  1,000,000+       BOA            Bank of Abyssinia
# 2     3911      771  1,000,000+    Dashen                  Dashen Bank

# %%
# Count reviews per bank

sql = """
SELECT r.bank_name, COUNT(*) AS total_reviews
FROM reviews v
JOIN banks r ON r.bank_code = v.bank_code
GROUP BY r.bank_name;
"""

run_query(sql)
# Out:
# C:\Users\Jose\AppData\Local\Temp\ipykernel_17248\1241105332.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, conn)
#                      bank_name  total_reviews
# 0                  Dashen Bank            380
# 1            Bank of Abyssinia            370
# 2  Commercial Bank of Ethiopia            375

# %%
# Average rating per restaurant

sql = """
SELECT r.bank_name, ROUND(AVG(v.rating), 2) AS avg_rating
FROM reviews v
JOIN banks r ON r.bank_code = v.bank_code
GROUP BY r.bank_name;
"""

run_query(sql)
# Out:
# C:\Users\Jose\AppData\Local\Temp\ipykernel_17248\1241105332.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, conn)
#                      bank_name  avg_rating
# 0                  Dashen Bank        3.95
# 1            Bank of Abyssinia        3.37
# 2  Commercial Bank of Ethiopia        4.14
